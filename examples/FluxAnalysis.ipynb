# %%
import sys
sys.path.append('/Users/tdinelli/Documents/GitHub/pySMOKEPostProcessor')
import pySMOKEPostProcessor as pp
from IPython.display import Image, display
import networkx as nx
import os

# %% [markdown]
# # Flux Analysis
#
# * Function to perform Flux Analysis (**`FluxAnalysis`**) accepts several arguments hereinafter reported:
#     > * `kinetic_folder` (*string*): path to the folder containing the files relative to the kinetic mechanism named directly, after the pre-processing by OpenSMOKE++: **kinetics.xml** and **reaction_names.xml**.
#     > * `output_folder` (*string*): path to the folder containing the files relative to the output of the simulations that are directly generated by OpenSMOKE++. Depending on the need different files are required. For the computation of the Flux Analysis only the file named **Output.xml** is required.
#     > * `species` (*string*): the name of the specie on which the flux analysis is wanted.
#     > * `element` (*string*): the name of the element on which to perform the flux analysis. It is important that the specie selected for the flux analysis have to contain the element selected.
#     > * `flux_analysis_type` (*string*): select the types of flux analtysis available. Two types settings are available "destruction" and "production".
#     > * `thickness` (*string*): sets the thickness of the "arrows" in the graph. Two type of settings are available "absolute" and "relative (%)".
#     > * `thickness_log_scale` (*bool*): select whether or not the thickness has to be computed using the logarithmic scale.
#     > * `label_type` (*string*): select the type of the labels appearing on the graph "absolute" or "relative (%)".
#     > * `depth` (*int* default: 2): maximum depth of the graph.
#     > * `width` (*int* default: 5): maximum width of the graph.
#     > * `threshold` (*float* default: 0.01): threshold to retain the reaction rate.
#     > * `local_value` (*float*): value where to select the reaction rates.
#
# You can either decide to show the entire graph and/or save it as png, as in the next cell, print the string in dot language used to generate the graph or either since the graph is generated through the use of `networkx` library you can decide to visualize only certain paths or extract different informations.

# %%
kineticFolder1 = "/Users/tdinelli/Desktop/HYDROGEN/ROPE/mechanisms/H2_ORIGINAL/kinetics" 
resultsFolder1 = "/Users/tdinelli/Desktop/HYDROGEN/ROPE/Output-original_air/Case12"
resultsFolder1 = "/Users/tdinelli/Desktop/HYDROGEN/ROPE/Output-original_air/Case20"

G = pp.FluxAnalysis(kinetic_folder=kineticFolder1, 
                    output_folder=resultsFolder1,
                    species = "H2", 
                    element = "H", 
                    flux_analysis_type = "destruction", 
                    thickness = "relative", 
                    thickness_log_scale = True, 
                    label_type = "relative", 
                    depth = 3, 
                    width = 6, 
                    threshold = 0.001, 
                    local_value = 1.5132)

P = nx.drawing.nx_pydot.to_pydot(G)
img = Image(P.create_png())  
display(img)
# Out:
# /var/folders/bw/lf_0rsnd7_zfc5zsmkvw94x1gkds83/T/ipykernel_16122/953319821.py:18: DeprecationWarning: nx.nx_pydot.to_pydot depends on the pydot package, which hasknown issues and is not actively maintained.
#
# See https://github.com/networkx/networkx/issues/5723
#   P = nx.drawing.nx_pydot.to_pydot(G)

# %%
kineticFolder2 = "/Users/tdinelli/Desktop/HYDROGEN/ROPE/mechanisms/H2_UPDATE/kinetics" 
resultsFolder2 = "/Users/tdinelli/Desktop/HYDROGEN/ROPE/Output-UPDATE_air/Case12"
resultsFolder2 = "/Users/tdinelli/Desktop/HYDROGEN/ROPE/Output-UPDATE_air/Case20"

G = pp.FluxAnalysis(kinetic_folder=kineticFolder2, 
                    output_folder=resultsFolder2,
                    species = "H2", 
                    element = "H", 
                    flux_analysis_type = "destruction", 
                    thickness = "relative", 
                    thickness_log_scale = True, 
                    label_type = "relative", 
                    depth = 3, 
                    width = 6, 
                    threshold = 0.01, 
                    local_value = 1.5088)

P = nx.drawing.nx_pydot.to_pydot(G)
img = Image(P.create_png())  
display(img)
# Out:
# /var/folders/bw/lf_0rsnd7_zfc5zsmkvw94x1gkds83/T/ipykernel_16122/1947831.py:18: DeprecationWarning: nx.nx_pydot.to_pydot depends on the pydot package, which hasknown issues and is not actively maintained.
#
# See https://github.com/networkx/networkx/issues/5723
#   P = nx.drawing.nx_pydot.to_pydot(G)

# %%
kineticFolder3 = "/Users/tdinelli/Desktop/HYDROGEN/ROPE/mechanisms/H2_UPDATE_MR/kinetics" 
resultsFolder3 = "/Users/tdinelli/Desktop/HYDROGEN/ROPE/Output-MR_air/Case12"
resultsFolder3 = "/Users/tdinelli/Desktop/HYDROGEN/ROPE/Output-MR_air/Case20"

G = pp.FluxAnalysis(kinetic_folder=kineticFolder3, 
                    output_folder=resultsFolder3,
                    species = "H2", 
                    element = "H", 
                    flux_analysis_type = "destruction", 
                    thickness = "relative", 
                    thickness_log_scale = True, 
                    label_type = "relative", 
                    depth = 3, 
                    width = 6, 
                    threshold = 0.01, 
                    local_value = 1.4934)

P = nx.drawing.nx_pydot.to_pydot(G)
img = Image(P.create_png())  
display(img)
# Out:
# /var/folders/bw/lf_0rsnd7_zfc5zsmkvw94x1gkds83/T/ipykernel_16122/792385838.py:18: DeprecationWarning: nx.nx_pydot.to_pydot depends on the pydot package, which hasknown issues and is not actively maintained.
#
# See https://github.com/networkx/networkx/issues/5723
#   P = nx.drawing.nx_pydot.to_pydot(G)

# %%
near_nodes = ['H2']
for node in G['H2']:
    near_nodes.append(node)
H = G.subgraph(near_nodes)
P = nx.drawing.nx_pydot.to_pydot(H)
img = Image(P.create_png()) 
display(img)
# Out:
# /var/folders/bw/lf_0rsnd7_zfc5zsmkvw94x1gkds83/T/ipykernel_31756/4208098854.py:5: DeprecationWarning: nx.nx_pydot.to_pydot depends on the pydot package, which hasknown issues and is not actively maintained.
#
# See https://github.com/networkx/networkx/issues/5723
#   P = nx.drawing.nx_pydot.to_pydot(H)

# %%
H = G.subgraph(['H2', 'NH3', 'H2O', 'H2O2', 'HO2'])
P = nx.drawing.nx_pydot.to_pydot(H)
img = Image(P.create_png()) 
display(img)
# Out:
# /var/folders/bw/lf_0rsnd7_zfc5zsmkvw94x1gkds83/T/ipykernel_31756/3760072166.py:2: DeprecationWarning: nx.nx_pydot.to_pydot depends on the pydot package, which hasknown issues and is not actively maintained.
#
# See https://github.com/networkx/networkx/issues/5723
#   P = nx.drawing.nx_pydot.to_pydot(H)
