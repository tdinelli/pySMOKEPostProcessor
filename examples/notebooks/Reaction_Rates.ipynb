# %%
from pySMOKEPostProcessor import PostProcessor
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# ### GetReactionRates
# function that returns the reaction rate in [kmol/m3/s] of a specific reaction.
#    > * `abscissae_name` ( *string* ): name of the abscissae for which is desired the plot of the reaction rate
#    > * `reaction_name` ( *string* ): name of the reaction for which is required the reaction rate

# %%
kineticFolder = os.path.join("data", "ROPA-01", "kinetics")
resultsFolder = os.path.join("data", "ROPA-01", "Output")

abscissae, reaction_rate = pp.GetReactionRates(kinetic_folder = kineticFolder,
                                            output_folder = resultsFolder,
                                            abscissae_name = 'temperature', 
                                            reaction_name = 'O2+H=O+OH')
plt.plot(abscissae, reaction_rate, 'r')
plt.xlabel('Temperature [K]', fontsize=15)
plt.ylabel('Reaction Rate [kmol/m3/s]', fontsize=15)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 kineticFolder = os.path.join("data", "ROPA-01", "kinetics")
#       2 resultsFolder = os.path.join("data", "ROPA-01", "Output")
# ----> 4 abscissae, reaction_rate = pp.GetReactionRates(kinetic_folder = kineticFolder,
#       5                                             output_folder = resultsFolder,
#       6                                             abscissae_name = 'temperature',
#       7                                             reaction_name = 'O2+H=O+OH')
#       8 plt.plot(abscissae, reaction_rate, 'r')
#       9 plt.xlabel('Temperature [K]', fontsize=15)
#
# File ~/Documents/GitHub/pySMOKEPostProcessor/pySMOKEPostProcessor/ropa.py:80, in GetReactionRates(kinetic_folder, output_folder, abscissae_name, reaction_name)
#      77 output_folder = get_c_string(output_folder)
#      79 f_handle = backend.handle.GetReactionRates
# ---> 80 backend.call(f_handle,
#      81 			kinetic_folder,
#      82 			output_folder,
#      83 			reaction_index,
#      84 			reaction_rates)
#      86 reaction_rates = c_array_to_list(reaction_rates, number_of_abscissae)
#      88 return x_axis, reaction_rates
#
# File ~/Documents/GitHub/pySMOKEPostProcessor/pySMOKEPostProcessor/postprocessor_backend.py:96, in PostProcessorBackend.call(self, function, *args)
#      89 def call(self, function, *args):
#      90 	"""
#      91 	Make a call to the C++ back-end
#      92 	:param function: What function to call
#      93 	:param args: Arguments to the function
#      94 	:return: Return value of the function
#      95 	"""
# ---> 96 	res = function(*args)
#      98 	if self.handle.postprocessor_get_error():
#      99 		# TODO: Sometimes the string is correct, sometimes not. Investigate.
#     100 		errorMsg = get_py_string(self.handle.postprocessor_get_error_string())
#
# TypeError: this function takes at least 5 arguments (4 given)

# %%
abscissae, reaction_rate_1 = pp.GetReactionRates(kinetic_folder = kineticFolder,
                                            output_folder = resultsFolder,
                                            abscissae_name = 'temperature', 
                                            reaction_name = 'O2+H=O+OH')

abscissae, reaction_rate_2 = pp.GetReactionRates(kinetic_folder = kineticFolder,
                                            output_folder = resultsFolder,
                                            abscissae_name = 'temperature', 
                                            reaction_name = 'H2+O=H+OH')

abscissae, reaction_rate_3 = pp.GetReactionRates(kinetic_folder = kineticFolder,
                                            output_folder = resultsFolder,
                                            abscissae_name = 'temperature', 
                                            reaction_name = 'O2+H(+M)=HO2(+M)')

plt.plot(abscissae, reaction_rate_1, 'r', label = 'O2+H=O+OH')
plt.plot(abscissae, reaction_rate_2, 'b', label = 'H2+O=H+OH')
plt.plot(abscissae, reaction_rate_3, 'g', label = 'O2+H(+M)=HO2(+M)')
plt.xlabel('Temperature [K]', fontsize=15)
plt.ylabel('Reaction Rate [kmol/m3/s]', fontsize=15)
plt.legend()
plt.grid()
plt.show()
